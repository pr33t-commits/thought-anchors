# %%
import json

# %%
with open("Results/deep_thinking_tokens_distances.json") as f:
    data = json.load(f)

# %%
import pandas as pd
pd.DataFrame(data['1923']['2'])
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.996094  0.996094  0.996094  0.996094  0.996094  0.996094  0.996094
#
#           7         8         9  ...        18        19        20        21  \
# 0  0.996094  0.996094  0.996094  ...  0.980469  0.972656  0.914062  0.777344
#
#          22        23        24        25        26   27
# 0  0.585938  0.425781  0.316406  0.398438  0.271484  0.0
#
# [1 rows x 28 columns]

# %%
pd.DataFrame(data['1591']['0']).insert(0, 'token', range(len(data['1591']['0']['0'])))

# %%
len(data['1591']['0']['0'])
# Out:
# 13
